# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Find representative producer countries

# %%
df = pd.read_excel('imap_export.xls', header=1)
df
# Out:
#                                Factory Name                 Factory Type  \
# 0                       A & K Designs, Inc.               FINISHED GOODS
# 1            ACode Sporting Goods Co., Ltd.               FINISHED GOODS
# 2                                 Ad Dulyal               FINISHED GOODS
# 3                    ADORA FOOTWEAR LIMITED               FINISHED GOODS
# 4             AHP APPAREL PVT LTD., UNIT 60               FINISHED GOODS
# ..                                      ...                          ...
# 638                               LELABPLUS               FINISHED GOODS
# 639                       Haivina Co., Ltd.               FINISHED GOODS
# 640             Tower Garments (London) Ltd               FINISHED GOODS
# 641  QINGDAO HONGTAISHENGDA TRADE CO., LTD.  FINISHED GOODS - COMPONENTS
# 642         Cygnus Investments S.A. de C.V.               FINISHED GOODS
#
#     Product Type Type Nike, Inc. Brand(s)      Events  \
# 0             Apparel                Nike         NaN
# 1           Equipment                Nike         NaN
# 2             Apparel                Nike         NaN
# 3            Footwear            Converse         NaN
# 4             Apparel                Nike  Collegiate
# ..                ...                 ...         ...
# 638           Apparel                Nike         NaN
# 639         Equipment                Nike         NaN
# 640           Apparel                Nike         NaN
# 641          Footwear                Nike         NaN
# 642           Apparel                Nike  Collegiate
#
#                              Supplier Group  \
# 0                             A & K DESIGNS
# 1                 EXCELLENCE SPORTING GOODS
# 2                              MAS HOLDINGS
# 3                                     HUALI
# 4                                     SHAHI
# ..                                      ...
# 638                                   LELAB
# 639                                 HAIVINA
# 640                          TOWER GARMENTS
# 641  QINGDAO HONGTAISHENGDA TRADE CO., LTD.
# 642                                  CYGNUS
#
#                                     Address                City  \
# 0                    8564 NE Alderwood Road            Portland
# 1                 No 32 VSIP II A Street 31        Bac Tan Uyen
# 2    Part of land no 1075 Basin 5 Ad Dulayl               Zarqa
# 3                    TAM DIEP INDUSTRY ZONE  Ninh Binh Province
# 4          207 ABDE F KIADB INDUSTRIAL AREA              HASSAN
# ..                                      ...                 ...
# 638               1 bis rue Jean le Galleu       Ivry sur Seine
# 639                      Lang Xuyen village  Hai Duong province
# 640             Unit J 17 Queensway Enfield             ENFIELD
# 641                       Beijingxi Road 41             Qingdao
# 642       Zona Franca Miramar Km 30 y medio           Olocuilta
#
#                 State Postal Code Country / Region    Region  Total Workers  \
# 0              Oregon       97220              USA  AMERICAS            111
# 1          Bình Duong      822710          Vietnam   SE ASIA            347
# 2            Az Zarqa       11183           Jordan      EMEA           1303
# 3           Ninh Bình      430000          Vietnam   SE ASIA           8120
# 4           Karnataka      573201            India    S ASIA           2704
# ..                ...         ...              ...       ...            ...
# 638     Île-de-France       94200           France      EMEA             21
# 639          Hi Duong      170000          Vietnam   SE ASIA           3259
# 640  London-- City of     EN3 4SA   United Kingdom      EMEA             90
# 641          Shandong      266300            China    N ASIA            100
# 642            La Paz       01608      El Salvador  AMERICAS            205
#
#      Line Workers  % Female Workers  % Migrant Workers
# 0              95                73                  0
# 1             318                79                  0
# 2            1166                87                 75
# 3            6800                86                  0
# 4             906                75                  0
# ..            ...               ...                ...
# 638            14                62                100
# 639          2870                96                  0
# 640            90                60                  0
# 641            80                90                  0
# 642           170                50                  0
#
# [643 rows x 16 columns]

# %%
workers_per_country = df.groupby(['Region', 'Country / Region']).sum()['Total Workers'].reset_index().sort_values(['Region', 'Total Workers'], ascending=False)
workers_per_country
# Out:
#       Region Country / Region  Total Workers
# 37   SE ASIA          Vietnam         509169
# 35   SE ASIA         Cambodia          56673
# 36   SE ASIA         Thailand          26432
# 31    S ASIA        Indonesia         279988
# 33    S ASIA         Pakistan          44785
# 30    S ASIA            India          43407
# 34    S ASIA        Sri Lanka          38311
# 32    S ASIA         Malaysia           7508
# 25    N ASIA            China         143361
# 29    N ASIA           Taiwan          12714
# 28    N ASIA      South Korea           3309
# 27    N ASIA      Philippines           2446
# 26    N ASIA            Japan           2063
# 12      EMEA            Egypt          12462
# 17      EMEA           Jordan           7229
# 23      EMEA           Turkey           6545
# 14      EMEA          Georgia           4570
# 9       EMEA           Bosnia           1998
# 16      EMEA            Italy           1606
# 19      EMEA          Moldova           1148
# 10      EMEA         Bulgaria            451
# 18      EMEA        Lithuania            324
# 21      EMEA     South Africa            221
# 15      EMEA           Israel            205
# 24      EMEA   United Kingdom             90
# 11      EMEA          Croatia             51
# 20      EMEA      Netherlands             31
# 13      EMEA           France             21
# 22      EMEA            Spain             16
# 1   AMERICAS           Brazil          21376
# 3   AMERICAS      El Salvador           7096
# 6   AMERICAS           Mexico           5169
# 7   AMERICAS        Nicaragua           4634
# 4   AMERICAS        Guatemala           4236
# 5   AMERICAS         Honduras           4128
# 8   AMERICAS              USA           3518
# 0   AMERICAS        Argentina           1457
# 2   AMERICAS           Canada            255

# %%
# Representative producer countries for each region
top_countries = workers_per_country.groupby('Region').head(1)
top_countries
# Out:
#       Region Country / Region  Total Workers
# 37   SE ASIA          Vietnam         509169
# 31    S ASIA        Indonesia         279988
# 25    N ASIA            China         143361
# 12      EMEA            Egypt          12462
# 1   AMERICAS           Brazil          21376

# %% [markdown]
# # Find representative consumer countries for each region
# - For top countries by consumption, we choose countries by GDP (https://en.wikipedia.org/wiki/List_of_countries_by_GDP_(nominal), sorted by forecast).
#     - North America - US, EMEA - Germany, Greater China - China, Asia Pacific - Japan, Latin America - Brazil
# - Ports for reference: largest port in the country (UN/LOCODE)
#     - US: Port of Los Angeles (USLAX)
#     - China: Port of Shanghai (CNSGH / CNSHA)
#     - Germany: Hamburg Port (DEHAM)
#     - India: Mundra (INMUN)
#     - Japan: Tokyo (JPTYO)
#     - Vietnam: Hai Phong (VNSIT)
#     - Indonesia: Tanjung Priok (IDTPR / IDTPP)
#     - Egypt: Port Said (EGPSD)
#     - Brazil: Santos (BRSSZ)

# %% [markdown]
# # Estimating transport cost (shipping + trucking cost) from producer region to consumer region
# - We use the Drewry World Container Index (https://en.macromicro.me/collections/4356/freight/44756/drewry-world-container-index) to get the overall trend of shipping cost.
# - Drewry tracks the freight costs of 40-foot container via eight major routes, including spot rates and short-term contract rates.
# - We take the cost in the first week of July, which is a good proxy for the average cost.
# - Because CMA-CGM and Freightos shipping costs are not always available between countries, we take a distance metric instead (https://www.geodatos.net/en/distances/countries).
# - We see that the Drewry World Container Index is very similar to the Drewry World Container Index - Shanghai to LA, and so we use that as a basis.
# - I checked the cost from Shanghai to LA on Freightos for a forty-foot and the cost is (exepctedly) very similar, so we can use the index directly.

# %%
years = np.arange(2014, 2024)
# Get Drewry World Container Index cost
global_shipping_costs = pd.DataFrame(
    {'year': years, # 10 years, 2014-2023
     'global_shipping_cost': [2053.72, 1583.27, 1427.14, 1549.72, 1468.18, 1372.11, 2031.57, 8399.09, 7050.94, 1474.32]})
global_shipping_costs
# Out:
#    year  global_shipping_cost
# 0  2014               2053.72
# 1  2015               1583.27
# 2  2016               1427.14
# 3  2017               1549.72
# 4  2018               1468.18
# 5  2019               1372.11
# 6  2020               2031.57
# 7  2021               8399.09
# 8  2022               7050.94
# 9  2023               1474.32

# %%
# Get distances (km)
data = {
    # Rows: ['SE ASIA - Vietnam', 'S ASIA - Indonesia', 'N ASIA - China', 'EMEA - Egypt', 'AMERICAS - Brazil']
    # Columns:
    'Asia Pacific': [3864, 4808, 3054, 9704, 17371], # 'Asia Pacific - Japan'
    'Greater China': [2450, 4181, 0, 6896, 16638], # 'Greater China - China'
    'EMEA': [9339, 11014, 7242, 3203, 9417], # 'EMEA - Germany'
    'North America': [13814, 14972, 11671, 10997, 7301], # 'North America - US'
    'Latin America': [17899, 17740, 16638, 10017, 0] # 'Latin America - Brazil'
}

# Rows (representative producer country)
# ['SE ASIA - Vietnam', 'S ASIA - Indonesia', 'N ASIA - China', 'EMEA - Egypt', 'AMERICAS - Brazil']
rows = ['SE ASIA', 'S ASIA', 'N ASIA', 'EMEA', 'AMERICAS']

# Create df
distances = pd.DataFrame(data, index=rows)
distances
# Out:
#           Asia Pacific  Greater China   EMEA  North America  Latin America
# SE ASIA           3864           2450   9339          13814          17899
# S ASIA            4808           4181  11014          14972          17740
# N ASIA            3054              0   7242          11671          16638
# EMEA              9704           6896   3203          10997          10017
# AMERICAS         17371          16638   9417           7301              0

# %%
# Normalize distances such that the distance from China to US is 1
transport_costs = distances / 11671
transport_costs = transport_costs.reset_index().melt(id_vars=['index'], var_name='Column', value_name='Value')
transport_costs = transport_costs.rename(columns={'index':'producer_region', 'Column':'consumer_region', 'Value':'distance'})
transport_costs
# Out:
#    producer_region consumer_region  distance
# 0          SE ASIA    Asia Pacific  0.331077
# 1           S ASIA    Asia Pacific  0.411961
# 2           N ASIA    Asia Pacific  0.261674
# 3             EMEA    Asia Pacific  0.831463
# 4         AMERICAS    Asia Pacific  1.488390
# 5          SE ASIA   Greater China  0.209922
# 6           S ASIA   Greater China  0.358238
# 7           N ASIA   Greater China  0.000000
# 8             EMEA   Greater China  0.590866
# 9         AMERICAS   Greater China  1.425585
# 10         SE ASIA            EMEA  0.800189
# 11          S ASIA            EMEA  0.943707
# 12          N ASIA            EMEA  0.620512
# 13            EMEA            EMEA  0.274441
# 14        AMERICAS            EMEA  0.806872
# 15         SE ASIA   North America  1.183618
# 16          S ASIA   North America  1.282838
# 17          N ASIA   North America  1.000000
# 18            EMEA   North America  0.942250
# 19        AMERICAS   North America  0.625568
# 20         SE ASIA   Latin America  1.533630
# 21          S ASIA   Latin America  1.520007
# 22          N ASIA   Latin America  1.425585
# 23            EMEA   Latin America  0.858281
# 24        AMERICAS   Latin America  0.000000

# %%
# Estimate number of items that can fit in a 40-foot (40') container
# A Nike shoe box measures 14 x 7.5 x 5 inches (14" x 7.5" x 7") (https://www.kusashoes.com/how-big-is-a-nike-shoe-box/)
# Using this calculator (https://www.gigacalculator.com/calculators/container-loading-calculator.php), 
# we get an estimate of 5,148 shoe boxes per container.
quantity_per_container = 5148

# Estimate factor for trucking cost from supplier to port of origin and from port of destination to customer
# As an estimate, we assume each direction costs 50% of shipping costs, so we have a factor of 2
trucking_cost_factor = 2

# %%
# Multiply by global_shipping_cost to get the total shipping cost (for each year)
# Then divide by 5,148 to get the shipping cost per item (for each year)
# And multiple by a factor of 2 to factor in trucking cost (for each year)
for i, year in enumerate(years):
    transport_costs[f'shipping_cost_{str(year)}'] = transport_costs['distance'] * global_shipping_costs.iloc[i,1] / quantity_per_container * trucking_cost_factor
transport_costs
# Out:
#    producer_region consumer_region  distance  shipping_cost_2014  \
# 0          SE ASIA    Asia Pacific  0.331077            0.264157
# 1           S ASIA    Asia Pacific  0.411961            0.328692
# 2           N ASIA    Asia Pacific  0.261674            0.208782
# 3             EMEA    Asia Pacific  0.831463            0.663400
# 4         AMERICAS    Asia Pacific  1.488390            1.187543
# 5          SE ASIA   Greater China  0.209922            0.167491
# 6           S ASIA   Greater China  0.358238            0.285828
# 7           N ASIA   Greater China  0.000000            0.000000
# 8             EMEA   Greater China  0.590866            0.471435
# 9         AMERICAS   Greater China  1.425585            1.137433
# 10         SE ASIA            EMEA  0.800189            0.638447
# 11          S ASIA            EMEA  0.943707            0.752956
# 12          N ASIA            EMEA  0.620512            0.495089
# 13            EMEA            EMEA  0.274441            0.218968
# 14        AMERICAS            EMEA  0.806872            0.643780
# 15         SE ASIA   North America  1.183618            0.944374
# 16          S ASIA   North America  1.282838            1.023539
# 17          N ASIA   North America  1.000000            0.797871
# 18            EMEA   North America  0.942250            0.751794
# 19        AMERICAS   North America  0.625568            0.499122
# 20         SE ASIA   Latin America  1.533630            1.223639
# 21          S ASIA   Latin America  1.520007            1.212769
# 22          N ASIA   Latin America  1.425585            1.137433
# 23            EMEA   Latin America  0.858281            0.684798
# 24        AMERICAS   Latin America  0.000000            0.000000
#
#     shipping_cost_2015  shipping_cost_2016  shipping_cost_2017  \
# 0             0.203646            0.183564            0.199330
# 1             0.253398            0.228410            0.248028
# 2             0.160956            0.145084            0.157545
# 3             0.511433            0.461000            0.500596
# 4             0.915510            0.825230            0.896110
# 5             0.129123            0.116390            0.126387
# 6             0.220353            0.198623            0.215683
# 7             0.000000            0.000000            0.000000
# 8             0.363442            0.327603            0.355741
# 9             0.876879            0.790408            0.858297
# 10            0.492197            0.443660            0.481767
# 11            0.580475            0.523233            0.568174
# 12            0.381678            0.344040            0.373590
# 13            0.168809            0.152162            0.165232
# 14            0.496308            0.447366            0.485791
# 15            0.728044            0.656250            0.712617
# 16            0.789075            0.711262            0.772354
# 17            0.615101            0.554444            0.602067
# 18            0.579579            0.522425            0.567297
# 19            0.384787            0.346843            0.376634
# 20            0.943338            0.850313            0.923348
# 21            0.934958            0.842759            0.915146
# 22            0.876879            0.790408            0.858297
# 23            0.527930            0.475869            0.516743
# 24            0.000000            0.000000            0.000000
#
#     shipping_cost_2018  shipping_cost_2019  shipping_cost_2020  \
# 0             0.188843            0.176486            0.261308
# 1             0.234978            0.219602            0.325147
# 2             0.149256            0.139489            0.206531
# 3             0.474257            0.443224            0.656245
# 4             0.848961            0.793409            1.174735
# 5             0.119737            0.111902            0.165684
# 6             0.204335            0.190964            0.282745
# 7             0.000000            0.000000            0.000000
# 8             0.337023            0.314970            0.466350
# 9             0.813137            0.759930            1.125165
# 10            0.456418            0.426553            0.631561
# 11            0.538279            0.503057            0.744835
# 12            0.353933            0.330774            0.489749
# 13            0.156538            0.146295            0.216607
# 14            0.460230            0.430115            0.636836
# 15            0.675122            0.630945            0.934189
# 16            0.731716            0.683836            1.012500
# 17            0.570389            0.533065            0.789266
# 18            0.537449            0.502281            0.743686
# 19            0.356817            0.333468            0.493739
# 20            0.874765            0.817525            1.210442
# 21            0.866994            0.810263            1.199689
# 22            0.813137            0.759930            1.125165
# 23            0.489554            0.457520            0.677412
# 24            0.000000            0.000000            0.000000
#
#     shipping_cost_2021  shipping_cost_2022  shipping_cost_2023
# 0             1.080321            0.906917            0.189632
# 1             1.344250            1.128483            0.235961
# 2             0.853856            0.716802            0.149880
# 3             2.713104            2.277620            0.476240
# 4             4.856691            4.077136            0.852511
# 5             0.684986            0.575038            0.120238
# 6             1.168950            0.981320            0.205190
# 7             0.000000            0.000000            0.000000
# 8             1.928026            1.618556            0.338433
# 9             4.651754            3.905094            0.816538
# 10            2.611055            2.191951            0.458327
# 11            3.079362            2.585089            0.540531
# 12            2.024763            1.699765            0.355413
# 13            0.895514            0.751774            0.157193
# 14            2.632863            2.210258            0.462155
# 15            3.862203            3.242275            0.677945
# 16            4.185964            3.514069            0.734776
# 17            3.263050            2.739293            0.572774
# 18            3.074609            2.581099            0.539696
# 19            2.041258            1.713613            0.358309
# 20            5.004312            4.201063            0.878423
# 21            4.959858            4.163744            0.870620
# 22            4.651754            3.905094            0.816538
# 23            2.800614            2.351084            0.491601
# 24            0.000000            0.000000            0.000000

# %% [markdown]
# ### Comments
# The transport cost is typically $0.20-$1.00 per pair of shoes, but spiked to $1.00-$4 during Covid-19 (2021-2022). Looks reasonable.

# %%
# Save as csv file
transport_costs.to_csv('transport_costs.csv', index=False)
